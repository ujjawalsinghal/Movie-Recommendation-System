# %%
import pandas as pd

# %%
data = {
    "title": ["The Shawshank Redemption", "The Godfather", "The Dark Knight", "Pulp Fiction", "Forrest Gump"],
    "rating": [9.3, 9.2, 9.0, 8.9, 8.8]
}
movies = pd.DataFrame(data)

movies
# Out:
#                       title  rating
# 0  The Shawshank Redemption     9.3
# 1             The Godfather     9.2
# 2           The Dark Knight     9.0
# 3              Pulp Fiction     8.9
# 4              Forrest Gump     8.8

# %%
movies.shape
# Out:
# (5, 2)

# %%
movies.columns
# Out:
# Index(['title', 'rating'], dtype='str')

# %%
movies["title"]
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3                Pulp Fiction
# 4                Forrest Gump
# Name: title, dtype: str

# %%
movies["rating"]
# Out:
# 0    9.3
# 1    9.2
# 2    9.0
# 3    8.9
# 4    8.8
# Name: rating, dtype: float64

# %%
movies.head()
# Out:
#                       title  rating
# 0  The Shawshank Redemption     9.3
# 1             The Godfather     9.2
# 2           The Dark Knight     9.0
# 3              Pulp Fiction     8.9
# 4              Forrest Gump     8.8

# %%
import pandas as pd

movies = pd.read_csv("../data/tmdb_5000_movies.csv")
credits = pd.read_csv("../data/tmdb_5000_credits.csv")

# %%
print("Movies shape:", movies.shape)
print("Credits shape:", credits.shape)
# Out:
# Movies shape: (4803, 20)
# Credits shape: (4803, 4)

# %%
print("Movies columns:")
print(movies.columns)

print("\nCredits columns:")
print(credits.columns)
# Out:
# Movies columns:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='str')
#
# Credits columns:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='str')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies[["title", "genres", "keywords", "overview"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
# ...

# %%
credits[["title", "cast", "crew"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies[["title", "genres", "keywords", "overview"]].isnull().sum()
# Out:
# title       0
# genres      0
# keywords    0
# overview    3
# dtype: int64

# %%
credits[["title", "cast", "crew"]].isnull().sum()
# Out:
# title    0
# cast     0
# crew     0
# dtype: int64

# %%
movies[["title", "genres", "keywords", "overview"]].dtypes
# Out:
# title       str
# genres      str
# keywords    str
# overview    str
# dtype: object

# %%
credits[["title", "cast", "crew"]].dtypes
# Out:
# title    str
# cast     str
# crew     str
# dtype: object

# %%
type(movies.loc[0, "genres"])
# Out:
# str

# %%
print(movies.loc[0, "genres"])
print(type(movies.loc[0, "genres"]))
# Out:
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
# <class 'str'>

# %%
import ast

genres = ast.literal_eval(movies.loc[0, "genres"])

print(genres)
print(type(genres))
# Out:
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]
# <class 'list'>

# %%
for genre in genres:
    print(genre["name"])
# Out:
# Action
# Adventure
# Fantasy
# Science Fiction

# %%
genre
# Out:
# {'id': 878, 'name': 'Science Fiction'}

# %%
genre["name"]
# Out:
# 'Science Fiction'

# %%
def convert_genres(text):
    genre_list = ast.literal_eval(text)

    name = []
    for genre in genre_list:
        name.append(genre["name"])

    return " ".join(name)

# %%
convert_genres(movies.loc[0, "genres"])
# Out:
# 'Action Adventure Fantasy Science Fiction'

# %%
movies["genres"] = movies["genres"].apply(convert_genres)

# %%
movies[["title", "genres"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                      genres
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction

# %%
def convert_names(text):
    items = ast.literal_eval(text)

    names = []

    for item in items:
        names.append(item["name"])
    return " ".join(names)

# %%
movies["keywords"] = movies["keywords"].apply(convert_names)

# %%
movies[["title", "keywords"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             keywords
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2  spy based on novel secret agent sequel mi6 bri...
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...

# %%
movies[["title", "genres", "keywords"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                      genres  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                             keywords
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2  spy based on novel secret agent sequel mi6 bri...
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...

# %%
def convert_cast(text):
    cast_list = ast.literal_eval(text)

    names = []

    for cast in cast_list[:3]:  # Limit to the first 3 cast members
        names.append(cast["name"])
    return " ".join(names)

# %%
movies["cast"] = credits["cast"].apply(convert_cast)

# %%
movies[["title", "cast"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                            cast
# 0  Sam Worthington Zoe Saldana Sigourney Weaver
# 1     Johnny Depp Orlando Bloom Keira Knightley
# 2      Daniel Craig Christoph Waltz Léa Seydoux
# 3      Christian Bale Michael Caine Gary Oldman
# 4    Taylor Kitsch Lynn Collins Samantha Morton

# %%
def get_director(text):
    crew_list = ast.literal_eval(text)

    for crew in crew_list:
        if crew["job"] == "Director":
            return crew["name"]
    return ""

# %%
movies["director"] = credits["crew"].apply(get_director)

# %%
movies[["title", "director"]].head()
# Out:
#                                       title           director
# 0                                    Avatar      James Cameron
# 1  Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                   Spectre         Sam Mendes
# 3                     The Dark Knight Rises  Christopher Nolan
# 4                               John Carter     Andrew Stanton

# %%
movies[["id", "title", "genres", "keywords", "cast", "director"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                      genres  \
# 0  Action Adventure Fantasy Science Fiction
# 1                  Adventure Fantasy Action
# 2                    Action Adventure Crime
# 3               Action Crime Drama Thriller
# 4          Action Adventure Science Fiction
#
#                                             keywords  \
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2  spy based on novel secret agent sequel mi6 bri...
# 3  dc comics crime fighter terrorist secret ident...
# 4  based on novel mars medallion space travel pri...
#
#                                            cast           director
# ...

# %%
movies["overview"] = movies["overview"].fillna("")

# %%
movies["overview"].isnull().sum()
# Out:
# np.int64(0)

# %%
movies = movies[[ "title", "genres", "keywords", "overview", "cast", "director"]]

# %%
movies["tags"] = (
    movies["genres"] + " " + 
    movies["keywords"] + " " + 
    movies["overview"] + " " + 
    movies["cast"] + " " + 
    movies["director"]
)

# %%
movies[["title", "tags"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  Action Adventure Fantasy Science Fiction cultu...
# 1  Adventure Fantasy Action ocean drug abuse exot...
# 2  Action Adventure Crime spy based on novel secr...
# 3  Action Crime Drama Thriller dc comics crime fi...
# 4  Action Adventure Science Fiction based on nove...

# %%
movies["tags"] = movies["tags"].str.lower()

# %%
movies[["title", "tags"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  action adventure fantasy science fiction cultu...
# 1  adventure fantasy action ocean drug abuse exot...
# 2  action adventure crime spy based on novel secr...
# 3  action crime drama thriller dc comics crime fi...
# 4  action adventure science fiction based on nove...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=5000)

# %%
vectors = vectorizer.fit_transform(movies["tags"])

# %%
print(vectors.shape)
# Out:
# (4803, 5000)

# %%
vectorizer.get_feature_names_out()[:20]
# Out:
# array(['000', '007', '10', '100', '11', '12', '13', '14', '15', '16',
#        '17', '17th', '18', '18th', '19', '1930s', '1940s', '1950s',
#        '1960s', '1970s'], dtype=object)

# %%
print(type(vectors))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
print(similarity.shape)
# Out:
# (4803, 4803)

# %%
similarity[0]
# Out:
# array([1.        , 0.0370775 , 0.03319446, ..., 0.03121119, 0.04577036,
#        0.00799478], shape=(4803,))

# %%
list(enumerate(similarity[0][:10]))
# Out:
# [(0, np.float64(1.0000000000000002)),
#  (1, np.float64(0.03707749519433735)),
#  (2, np.float64(0.03319446092699622)),
#  (3, np.float64(0.0266833316193343)),
#  (4, np.float64(0.2323784443092509)),
#  (5, np.float64(0.08342565091841642)),
#  (6, np.float64(0.025765475708114507)),
#  (7, np.float64(0.09706524643115665)),
#  (8, np.float64(0.023551947366982403)),
#  (9, np.float64(0.03465972982352925))]

# %%
sorted(list(enumerate(similarity[0])), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [(0, np.float64(1.0000000000000002)),
#  (2403, np.float64(0.40502151583543555)),
#  (3158, np.float64(0.3536204624068246)),
#  (1531, np.float64(0.34480010913442444)),
#  (838, np.float64(0.3365465699682493)),
#  (1914, np.float64(0.3202185751905406)),
#  (2015, np.float64(0.30351143804230457)),
#  (4332, np.float64(0.29145997970028104)),
#  (373, np.float64(0.2795977577661536)),
#  (461, np.float64(0.27784918378509005))]

# %%
movies.iloc[2403]["title"]
# Out:
# 'Aliens'

# %%
movies.iloc[3158]["title"]
# Out:
# 'Alien'

# %%
movies.iloc[1531]["title"]
# Out:
# 'Moonraker'

# %%
for movie in sorted(list(enumerate(similarity[0])), 
                    key=lambda x: x[1], 
                    reverse=True)[1:6]:
    
    print(movies.iloc[movie[0]]["title"], "→", movie[1])
# Out:
# Aliens → 0.40502151583543555
# Alien → 0.3536204624068246
# Moonraker → 0.34480010913442444
# Alien³ → 0.3365465699682493
# Lifeforce → 0.3202185751905406

# %%
movie_indices = pd.Series(movies.index, index=movies["title"]).drop_duplicates()

# %%
movie_indices["Avatar"]
# Out:
# np.int64(0)

# %%
def recommend(movie):
    movie = movie.lower()

    title_map = {
        title.lower(): title
        for title in movies["title"]
    }

    if movie not in title_map:
        print("Movie not found in the dataset.")
        return []

    actual_title = title_map[movie]
    index = movie_indices[actual_title]

    similar_movies = sorted(
        list(enumerate(similarity[index])),
        key=lambda x: x[1],
        reverse=True
    )

    recommendations = []

    for i in similar_movies[1:6]:
        recommendations.append({
            "title": movies.iloc[i[0]]["title"],
            "score": float(round(i[1], 3))
        })

    return recommendations

# %%
recommend("Avatar")
# Out:
# Recommendations for: Avatar
#
# Aliens → 0.405
# Alien → 0.354
# Moonraker → 0.345
# Alien³ → 0.337
# Lifeforce → 0.32

# %%
recommend("The Dark Knight Rises")
# Out:
# Recommendations for: The Dark Knight Rises
#
# The Dark Knight → 0.508
# Batman Begins → 0.438
# Batman Returns → 0.422
# Batman → 0.395
# Batman Forever → 0.371

# %%
recommend("Avengers 999")
# Out:
# Movie not found in the dataset.

# %%
recommend("The Dark Knight Rises")
# Out:
# Recommendations for: The Dark Knight Rises
#
# The Dark Knight → 0.508
# Batman Begins → 0.438
# Batman Returns → 0.422
# Batman → 0.395
# Batman Forever → 0.371

# %%
recommend("Titanic")
# Out:
# Recommendations for: Titanic
#
# Romance & Cigarettes → 0.227
# In the Heart of the Sea → 0.225
# Captain Phillips → 0.223
# Poseidon → 0.216
# Ghost Ship → 0.215

# %%
movies["title"].duplicated().sum()
# Out:
# np.int64(3)

# %%
recommend("Avatar")
# Out:
# [{'title': 'Aliens', 'score': np.float64(0.405)},
#  {'title': 'Alien', 'score': np.float64(0.354)},
#  {'title': 'Moonraker', 'score': np.float64(0.345)},
#  {'title': 'Alien³', 'score': np.float64(0.337)},
#  {'title': 'Lifeforce', 'score': np.float64(0.32)}]

# %%
movies["title"].duplicated().sum()
# Out:
# np.int64(3)

# %%
movies[movies["title"].duplicated(keep=False)].sort_values("title")[["title"]]
# Out:
#                 title
# 1359           Batman
# 4267           Batman
# 3647  Out of the Blue
# 3693  Out of the Blue
# 972          The Host
# 2877         The Host

# %%
recommend("AVATAR")
# Out:
# [{'title': 'Aliens', 'score': 0.405},
#  {'title': 'Alien', 'score': 0.354},
#  {'title': 'Moonraker', 'score': 0.345},
#  {'title': 'Alien³', 'score': 0.337},
#  {'title': 'Lifeforce', 'score': 0.32}]

# %%
recommend("Avatar")
# Out:
# [{'title': 'Aliens', 'score': 0.405},
#  {'title': 'Alien', 'score': 0.354},
#  {'title': 'Moonraker', 'score': 0.345},
#  {'title': 'Alien³', 'score': 0.337},
#  {'title': 'Lifeforce', 'score': 0.32}]

# %%
import sys
sys.path.append("..")

# %%
from src.recommender import hello

print(hello())
# Out:
# Recommendation system is working!

# %%
import sys
sys.path.append("..")

# %%
from src.recommender import recommend

# %%
recommend("Avatar")
# Out:
# [{'title': 'Aliens', 'score': 0.405},
#  {'title': 'Alien', 'score': 0.354},
#  {'title': 'Moonraker', 'score': 0.345},
#  {'title': 'Alien³', 'score': 0.337},
#  {'title': 'Lifeforce', 'score': 0.32}]

# %%
import sys
sys.path.append("..")

# %%
from src.recommender import recommend

recommend("Avatar")
# Out:
# [{'id': 679, 'title': 'Aliens', 'score': 0.405},
#  {'id': 348, 'title': 'Alien', 'score': 0.354},
#  {'id': 698, 'title': 'Moonraker', 'score': 0.345},
#  {'id': 8077, 'title': 'Alien³', 'score': 0.337},
#  {'id': 11954, 'title': 'Lifeforce', 'score': 0.32}]

# %%
from src.tmdb import get_poster

# %%
from src.tmdb import get_poster

poster = get_poster(19995)
print(poster)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File e:\Movie-Recommendation-System\venv\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# ...
